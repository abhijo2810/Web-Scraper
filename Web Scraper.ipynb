# %%
import requests
from bs4 import BeautifulSoup
import pprint

res = requests.get('https://news.ycombinator.com/news')
soup = BeautifulSoup(res.text, 'html.parser')
links = soup.select('.titleline')
subtext = soup.select('.subtext')


def sort_stories(hnlist):
  return sorted(hnlist, key= lambda k:k['votes'], reverse=True)


def create_custom_hn(links, votes):
  hn =[]
  for inx, item in enumerate(links):
    title = links[inx].getText()
    href = links[inx].get('href', None)
    vote = subtext[inx].select('.score')
    if len(vote):
      points = int(vote[0].getText().replace(' points', ''))
      if points > 99:
        hn.append({'title': title, 'link': href, 'votes': points})
  return sort_stories(hn)


pprint.pprint(create_custom_hn(links, subtext))
# Out:
# [{'link': None,
#   'title': 'Show HN: LLMs can generate valid JSON 100% of the time '
#            '(github.com/normal-computing)',
#   'votes': 641},
#  {'link': None,
#   'title': 'Show HN: Little Rat – Chrome extension monitors network calls of '
#            'all extensions (github.com/dnakov)',
#   'votes': 443},
#  {'link': None,
#   'title': 'Backward Compatibility, Go 1.21, and Go 2 (go.dev)',
#   'votes': 341},
#  {'link': None,
#   'title': 'JWST spots giant black holes all over the early universe '
#            '(quantamagazine.org)',
#   'votes': 269},
#  {'link': None,
#   'title': 'OpenFarm – a free and open database and web application for '
#            'gardening knowledge (openfarm.cc)',
#   'votes': 257},
#  {'link': None,
#   'title': 'Show HN: AI-town, run your own custom AI world SIM with JavaScript '
#            '(github.com/a16z-infra)',
#   'votes': 228},
#  {'link': None,
#   'title': 'Elixir – Why the dot when calling anonymous functions? '
#            '(dashbit.co)',
#   'votes': 209},
#  {'link': None,
#   'title': 'Internet Archive responds to recording industry lawsuit targeting '
#            'obsolete media (archive.org)',
#   'votes': 187},
#  {'link': None,
#   'title': 'The anesthetic effect of air at atmospheric pressure (nih.gov)',
#   'votes': 178},
#  {'link': None,
#   'title': 'Tell HN: t.co is adding a five-second delay to some domains',
#   'votes': 159},
#  {'link': None,
#   'title': "Caught by MuseScore's Dark Patterns (2021) (gadanidis.ca)",
#   'votes': 140},
#  {'link': None,
#   'title': 'Does there exist a complete implementation of the Risch algorithm? '
#            '(mathoverflow.net)',
#   'votes': 115},
#  {'link': None,
#   'title': 'Launch HN: Serra (YC S23) – Open-core, Python-based dbt '
#            'alternative',
#   'votes': 112},
#  {'link': None,
#   'title': 'Study shows dementia more common in older adults with vision '
#            'issues (michiganmedicine.org)',
#   'votes': 110}]
